# %% [markdown]
# <a href="https://colab.research.google.com/github/tanusreeg/Machine-Learning-Tutorial/blob/main/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def gradient_descent(x,y):
  m=b=0
  n=len(x)
  learning_rate=0.01
  for i in range(1000):
    y_predicted = m*x+b
    loss=(1/n)*sum(val**2 for val in (y-y_predicted))
    md=-(2/n)*sum(x*(y-y_predicted))
    bd=-(2/n)*sum((y-y_predicted))
    m=m-learning_rate*md
    b=b-learning_rate*bd
    print("m = {}, b= {}, cost={}, y={}, y_pred={}, iteration={}".format(m,b,loss,y,y_predicted,i))

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
gradient_descent(x,y)
# Out:
# m = 0.62, b= 0.18, cost=89.0, y=[ 5  7  9 11 13], y_pred=[0 0 0 0 0], iteration=0
# m = 1.0928, b= 0.3192, cost=52.25039999999999, y=[ 5  7  9 11 13], y_pred=[0.8  1.42 2.04 2.66 3.28], iteration=1
# m = 1.453232, b= 0.42724799999999996, cost=30.831949440000002, y=[ 5  7  9 11 13], y_pred=[1.412  2.5048 3.5976 4.6904 5.7832], iteration=2
# m = 1.7278860800000002, b= 0.5115091199999999, cost=18.347751350784, y=[ 5  7  9 11 13], y_pred=[1.88048  3.333712 4.786944 6.240176 7.693408], iteration=3
# m = 1.9370605952000002, b= 0.5776057727999999, cost=11.070010749324897, y=[ 5  7  9 11 13], y_pred=[2.2393952  3.96728128 5.69516736 7.42305344 9.15093952], iteration=4
# m = 2.096250917888, b= 0.6298300216319999, cost=6.826353152519786, y=[ 5  7  9 11 13], y_pred=[ 2.51466637  4.45172696  6.38878756  8.32584815 10.26290875], iteration=5
# ...
